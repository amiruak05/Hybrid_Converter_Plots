# %% [markdown]
# <a href="https://colab.research.google.com/github/amiruak05/Hybrid_Converter_Plots/blob/main/myPaperGRAPH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tabulate import tabulate

# %%
path_a = "/content/a_Vout_at_K_V15Hz.csv"
a = pd.read_csv(path_a)
path_b = "/content/b_Pout_at_K_V15Hz.csv"
b = pd.read_csv(path_b)
path_c = "/content/c_Iout_at_K_V15Hz.csv"
c = pd.read_csv(path_c)
a, b, c
# Out:
# (   V1   V2  V_out
#  0  20   20   0.91
#  1  20   40   0.91
#  2  20   60   0.94
#  3  20   80   0.95
#  4  20  100   0.96,
#     V1   V2  P_out
#  0  20   20   82.9
#  1  20   40   82.9
#  2  20   60   88.5
#  3  20   80   90.5
#  4  20  100   92.6,
#     V1   V2  I_out
#  0  20   20   91.1
#  1  20   40   91.1
#  2  20   60   94.3
#  3  20   80   95.2
#  4  20  100   96.5)

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Plot A
axes[0].plot(a['V2'], a['V_out'])
axes[0].set_xlabel('DC Vin [mV]')
axes[0].set_ylabel('Vout [V]')
axes[0].set_title('Ouput Voltage at 20mVAC, 5Hz and Varrying DC source')

# Plot B
axes[1].plot(b['V2'], b['P_out'])
axes[1].set_xlabel('DC Vin [mV]')
axes[1].set_ylabel('P_out [µW]')
axes[1].set_title('Power output at 20mVAC, 5Hz and Varrying DC source')

# Plot C
axes[2].plot(c['V2'], c['I_out'])
axes[2].set_xlabel('DC Vin [mV]')
axes[2].set_ylabel('Iout [µA]')
axes[2].set_title('Output current at 20mVAC, 5Hz and Varrying DC source')

plt.tight_layout()
fig.savefig('abc_plots')
plt.show();

# %%
path_d = "/content/d_Vout_at_K_V25Hz.csv"
d = pd.read_csv(path_d)
path_e = "/content/e_Pout_at_K_V25Hz.csv"
e = pd.read_csv(path_e)
path_f = "/content/f_Iout_at_K_V25Hz.csv"
f = pd.read_csv(path_f)
d,e,f
# Out:
# (    V1  V2  V_out
#  0   20  20   0.91
#  1   40  20   2.00
#  2   60  20   3.20
#  3   80  20   4.30
#  4  100  20   5.50,
#      V1  V2   P_out
#  0   20  20    82.9
#  1   40  20   406.8
#  2   60  20  1015.4
#  3   80  20  1860.2
#  4  100  20  3014.0,
#      V1  V2  I_out
#  0   20  20   91.1
#  1   40  20  203.4
#  2   60  20  317.3
#  3   80  20  432.6
#  4  100  20  548.0)

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Plot D
axes[0].plot(d['V1'], d['V_out'])
axes[0].set_xlabel('AC Vin [mV]')
axes[0].set_ylabel('Vout [V]')
axes[0].set_title('Ouput Voltage at 20mVDC, 5Hz and Varrying AC voltages')

# Plot E
axes[1].plot(e['V1'], e['P_out'])
axes[1].set_xlabel('DC Vin [mV]')
axes[1].set_ylabel('P_out [µW]')
axes[1].set_title('Power output at 20mVDC, 5Hz and Varrying AC voltages')

# Plot F
axes[2].plot(f['V1'], c['I_out'])
axes[2].set_xlabel('DC Vin [mV]')
axes[2].set_ylabel('Iout [µA]')
axes[2].set_title('Output current at 20mVDC, 5Hz and Varrying AC voltages')

plt.tight_layout()
fig.savefig('def_plots')
plt.show();

# %%
path_g = "/content/g_Vout_at_K_V1V2.csv"
g = pd.read_csv(path_g)
path_h = "/content/h_Pout_at_K_V1V2.csv"
h = pd.read_csv(path_h)
path_i = "/content/i_Iout_at_K_V1V2.csv"
i = pd.read_csv(path_i)
g,h,i
# Out:
# (   V1  Frequency  V_out
#  0  20          2   0.39
#  1  20          4   0.78
#  2  20          5   0.91
#  3  20          7   1.10
#  4  20         10   1.22,
#     V1  Frequency   P_out
#  0  20          2   15.40
#  1  20          4   60.84
#  2  20          5   83.36
#  3  20          7  119.57
#  4  20         10  149.33,
#     V1  Frequency  I_out
#  0  20          2   39.5
#  1  20          4   78.0
#  2  20          5   91.6
#  3  20          7  108.7
#  4  20         10  122.4)

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Plot G
axes[0].plot(g['Frequency'], g['V_out'])
axes[0].set_xlabel('Frequency [Hz]')
axes[0].set_ylabel('Vout [V]')
axes[0].set_title('Ouput Voltage at 20mVAC,20mVDC and Varrying Frequency')

# Plot H
axes[1].plot(h['Frequency'], h['P_out'])
axes[1].set_xlabel('Frequency [Hz]')
axes[1].set_ylabel('P_out [µW]')
axes[1].set_title('Power output at 20mVAC,20mVDC and Varrying Frequency')

# Plot I
axes[2].plot(i['Frequency'], i['I_out'])
axes[2].set_xlabel('Frequency [Hz]')
axes[2].set_ylabel('Iout [µA]')
axes[2].set_title('Output current at 20mVAC,20mVDC and Varrying Frequency')

plt.tight_layout()
fig.savefig('ghi_plots')
plt.show();
